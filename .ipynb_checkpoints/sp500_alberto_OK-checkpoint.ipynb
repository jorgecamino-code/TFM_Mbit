# %% [markdown]
# # Aplicamos el mismo Código al SXXP:

# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import holidays
# %matplotlib inline

# %%
# ELimina los warnings en la salida de la celda
warnings.simplefilter('ignore')

# %%
# Carga de datos de fichero pickle (9010, 31306) Ultimos 30 Años
data_sp = pd.read_pickle("C:/Users/pk_ai/Desktop/TFM/Datos INICIALES/data_componentes_SXXP.pkl")

# %%
data_sp_copy = data_sp

# %%
data_sp_copy.shape
# Out:
# (8066, 37793)

# %%
# Definir Año para filtrar
start_date  =  '2015-01-01'
data_sp['date'] = data_sp_copy.index
data_sp_copy.reset_index(drop=True)
# Out:
#      0876218D LN Equity                                                     \
#                    open high low close volume bid ask open_int cur_mkt_cap
# 0                   NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# 1                   NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# 2                   NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# 3                   NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# 4                   NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# ...                 ...  ...  ..   ...    ...  ..  ..      ...         ...
# 8061                NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# 8062                NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# 8063                NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# 8064                NaN  NaN NaN   NaN    NaN NaN NaN      NaN         NaN
# ...

# %%
# Aqui se filtra
data_sp_copy['date']=pd.to_datetime(data_sp_copy['date'])
datefilter  =  (data_sp_copy['date']  >  start_date )
data_sp_copy  =  data_sp_copy.loc[datefilter]

# %%
# resetear index
data_sp_copy.index = range(data_sp_copy.shape[0])

# %%
# guardar date en dataframe 
date = pd.DataFrame(data_sp_copy['date'])
date['date'] =  pd.to_datetime(date['date'])

# %%
# extraer nombres de compañias
company=[]
for i in data_sp_copy.columns:
    company.append(i[0])

# %%
company = list(dict.fromkeys(company))

# %%
def check(word, list):
    if word in list:
        print("word is in the list!")
    else:
        print("word is not in the list!")
check('date', company)
# Out:
# word is in the list!

# %%
# elimino date
removeWord = ['date']
company = [word for word in company if word not in removeWord]
check('date', company)
# Out:
# word is not in the list!

# %%
# creo una lista con cada companias como dataframe
dataframes = []
for i in company:
    dataframes.append(data_sp_copy[i])

# %%
# creo la columna company con cada nombre de la compañia
j=0
for i in company:
    #dataframes[j]['Company'] = i
    dataframes[j]['Date'] = date['date']
    j += 1

# %%
#Crear dataframe de tiempo con todos los dias (porque no estaban en el Accurate Quand data)
Timeframe = pd.date_range(start='1/01/2015', end='10/08/2019')
Timeframe = pd.DataFrame(Timeframe)
Timeframe.columns = ['Date']

# %%
# Añado los días que faltaban
j = 0
for i in dataframes:
    dataframes[j] = pd.merge(dataframes[j], Timeframe, on='Date', how='outer')
    dataframes[j].sort_values(by = ['Date'], inplace = True)
    dataframes[j] = dataframes[j].reset_index(drop=True)
    j += 1

# %%
# creo la columna company con cada nombre de la compañia
#j=0
#for i in company:
    #dataframes[j]['Company'] = i
#    j += 1

# %%
# Crear una variable para cada dataframe
# for i, val in enumerate(dataframes): 
#     globals()["dataframe_Sep_%d"%i] = val

# %%
# obtengo los holidays para UnitedStates en una lista para los años 2015-16-17-18-19
years = [2015, 2016, 2017, 2018, 2019]
holidays_date = []
for i in years:
    for j in holidays.UnitedStates(years=i).items():
        holidays_date.append(str(j[0]))

# %%
# Se crea una columna con 1 si el dia coincide con la lista creada de dias holidays
j = 0
for i in dataframes:
    dataframes[j].loc[dataframes[j]['Date'].isin(holidays_date), 'Holiday'] = 1
    j += 1

# %%
# Creo la columna Profitability ((close-open)/open*100) y Day_Week
# Si Week_day es Sabado o domingo o esa fecha es festiva ponme un 0 en el profitability porque no ha habido movimiento
j = 0
for i in dataframes:
    dataframes[j]['Day_Week'] = dataframes[j]['Date'].dt.weekday_name
    dataframes[j]['Month'] = dataframes[j]['Date'].dt.month
    dataframes[j]['YearMonth'] = dataframes[j]['Date'].dt.to_period('M')
    dataframes[j]['Profitability'] = (dataframes[j]['close']-dataframes[j]['open'])/dataframes[j]['open']*100
    dataframes[j].loc[(dataframes[j]['Day_Week'] == 'Saturday') | (dataframes[j]['Day_Week'] == 'Sunday') | (dataframes[j]['Holiday'] == 1), 'Profitability'] = 0
    j += 1

# %% [markdown]
# # Hasta aquí todo funciona de forma correcta.

# %% [markdown]
# # Celda que falla ya que hace que se ddeban de ejecutar 5 veces

# %%
test = dataframes.copy()

# %%
len(test)
# Out:
# 1394

# %%
dejar = []

# %%
## Revisar por que se tiene que ranear 5 veces aprox.
for j,i in enumerate(test):
    if i['Profitability'].isnull().mean() < 0.15:
        dejar.append(j)

test = [x for j,x in enumerate(test) if j in dejar]

# %%
len(test)
# Out:
# 848

# %% [markdown]
# # el for se ejecuta hasta llegar al valor final de long de lista 656

# %%
j = 0
for i in test:
    print('Dataset: ' + str(j) + ' | Null Values Profitability: ' + str(test[j]['Profitability'].isnull().sum()))
    j += 1
# Out:
# Dataset: 0 | Null Values Profitability: 117
# Dataset: 1 | Null Values Profitability: 232
# Dataset: 2 | Null Values Profitability: 39
# Dataset: 3 | Null Values Profitability: 31
# Dataset: 4 | Null Values Profitability: 52
# Dataset: 5 | Null Values Profitability: 39
# Dataset: 6 | Null Values Profitability: 31
# Dataset: 7 | Null Values Profitability: 51
# Dataset: 8 | Null Values Profitability: 51
# Dataset: 9 | Null Values Profitability: 39
# Dataset: 10 | Null Values Profitability: 31
# Dataset: 11 | Null Values Profitability: 250
# Dataset: 12 | Null Values Profitability: 31
# Dataset: 13 | Null Values Profitability: 31
# Dataset: 14 | Null Values Profitability: 39
# Dataset: 15 | Null Values Profitability: 31
# Dataset: 16 | Null Values Profitability: 31
# Dataset: 17 | Null Values Profitability: 31
# Dataset: 18 | Null Values Profitability: 31
# Dataset: 19 | Null Values Profitability: 51
# Dataset: 20 | Null Values Profitability: 51
# ...

# %%
test[0][test[0]['Profitability'].isnull()]

# %% [markdown]
# ## **Siguientes Pasos:**
# ### Mirar si estan todos los dias o cuales faltan (Hecho)
# ### Añadir dias que faltan (Hecho)
# ### Crear columna weekday (HECHO)
# ### Holiday (Hecho)
# ### sabados y domingos y holidays rentabilidad 0 (HECHO)
# ### Crear columna Mes (Hecho)
# ### Crear columna Año Mes (Hecho)
# # **Funcion de Manuel (NAs)**
# ### Aplicar medias moviles exponenciales PROBELMA!!!!!
# ## Rentabilidad media por Mes y la desviacion standard por mes
# ### Repasar por que no aparece toda la company values (hemos hecho el merge de fechas)

# %% [markdown]
# # Jose - Coger código de LSTM (MBIT)
# # Jose - Aplicarlo a 1 dataset = dataframes[0]

# %% [markdown]
# # Alberto - Buscar INformación de que hacer con las ventanas en series temporales
# ### Ventana = serie temporal con NAs en Profitability seguidos
#
# # Cual serí al mejor método de imputación

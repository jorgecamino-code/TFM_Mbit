# %%
import pandas as pd
data_sp = pd.read_csv("C:/Users/Carap/OneDrive/Escritorio/Datos TFM csv/componentes_SP500.csv")
data_sp
# Out:
#      Unnamed: 0 SPX_components SPX_components.1 SPX_components.2  \
# 0           NaN    0111145D UN      0202445Q UN      0203524D UN
# 1         index            NaN              NaN              NaN
# 2    2002-01-31           True             True             True
# 3    2002-02-28           True             True             True
# 4    2002-03-31           True             True             True
# 5    2002-04-30           True             True             True
# 6    2002-05-31           True             True             True
# 7    2002-06-30           True             True             True
# 8    2002-07-31           True             True             True
# 9    2002-08-31           True             True             True
# 10   2002-09-30           True             True             True
# 11   2002-10-31           True             True             True
# 12   2002-11-30           True             True             True
# ...
